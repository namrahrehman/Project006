# %%
# !pip install n2v
# Out:
# Collecting n2v
#   Downloading n2v-0.3.3-py2.py3-none-any.whl (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 1.6 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from n2v) (1.23.5)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.10/dist-packages (from n2v) (2023.9.26)
# Collecting imagecodecs>=2020.2.18 (from n2v)
#   Downloading imagecodecs-2023.9.18-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 39.5 MB/s eta 0:00:00
# Collecting csbdeep<0.8.0,>=0.7.2 (from n2v)
#   Downloading csbdeep-0.7.4-py2.py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 10.0 MB/s eta 0:00:00
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from n2v) (9.4.0)
# Collecting ruamel.yaml>=0.16.10 (from n2v)
#   Downloading ruamel.yaml-0.18.5-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.4/116.4 kB 15.7 MB/s eta 0:00:00
# Collecting bioimageio.core (from n2v)
#   Downloading bioimageio.core-0.5.11-py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.4/77.4 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (1.11.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (3.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (1.16.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (4.66.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from csbdeep<0.8.0,>=0.7.2->n2v) (23.2)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.16.10->n2v)
#   Downloading ruamel.yaml.clib-0.2.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.7/526.7 kB 46.7 MB/s eta 0:00:00
# Collecting bioimageio.spec==0.4.9.* (from bioimageio.core->n2v)
#   Downloading bioimageio.spec-0.4.9.post5-py3-none-any.whl (143 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.6/143.6 kB 19.2 MB/s eta 0:00:00
# Requirement already satisfied: imageio>=2.5 in /usr/local/lib/python3.10/dist-packages (from bioimageio.core->n2v) (2.31.6)
# Requirement already satisfied: xarray in /usr/local/lib/python3.10/dist-packages (from bioimageio.core->n2v) (2023.7.0)
# Collecting marshmallow-jsonschema (from bioimageio.spec==0.4.9.*->bioimageio.core->n2v)
#   Downloading marshmallow_jsonschema-0.13.0-py3-none-any.whl (11 kB)
# Collecting marshmallow-union (from bioimageio.spec==0.4.9.*->bioimageio.core->n2v)
#   Downloading marshmallow_union-0.1.15.post1-py2.py3-none-any.whl (4.6 kB)
# Collecting marshmallow<4.0,>=3.6.0 (from bioimageio.spec==0.4.9.*->bioimageio.core->n2v)
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (0.9.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (4.5.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (2.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (4.44.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->csbdeep<0.8.0,>=0.7.2->n2v) (2.8.2)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from xarray->bioimageio.core->n2v) (1.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->xarray->bioimageio.core->n2v) (2023.3.post1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (2023.7.22)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer->bioimageio.spec==0.4.9.*->bioimageio.core->n2v) (8.1.7)
# Installing collected packages: ruamel.yaml.clib, marshmallow, imagecodecs, ruamel.yaml, marshmallow-union, marshmallow-jsonschema, csbdeep, bioimageio.spec, bioimageio.core, n2v
# Successfully installed bioimageio.core-0.5.11 bioimageio.spec-0.4.9.post5 csbdeep-0.7.4 imagecodecs-2023.9.18 marshmallow-3.20.1 marshmallow-jsonschema-0.13.0 marshmallow-union-0.1.15.post1 n2v-0.3.3 ruamel.yaml-0.18.5 ruamel.yaml.clib-0.2.8

# %%
import tensorflow as tf
import n2v
print(tf.__version__)
print(n2v.__version__)
# Out:
# 2.14.0
# 0.3.3

# %%
from n2v.models import N2VConfig, N2V
import numpy as np
from csbdeep.utils import plot_history
from n2v.utils.n2v_utils import manipulate_val_data
from n2v.internals.N2V_DataGenerator import N2V_DataGenerator
from matplotlib import pyplot as plt
import urllib
import os
import zipfile

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
datagen = N2V_DataGenerator()

# %%
imgs = datagen.load_imgs_from_directory(directory = "/content/",
                                        filter='*.png',dims='YXC')  #ZYX for 3D

# Let's look at the shape of the image
print('shape of loaded images: ',imgs[0].shape)
# If the image has four color channels (stored in the last dimension): RGB and Aplha.
# We are not interested in Alpha and will get rid of it.
imgs[0] = imgs[0][...,:3]
print('shape without alpha:    ',imgs[0].shape)
print('The data type of the first image is: ', imgs[0].dtype)
# Out:
# shape of loaded images:  (1, 755, 927, 4)
# shape without alpha:     (1, 755, 927, 3)
# The data type of the first image is:  float32

# %%
print(len(imgs))
print(imgs[0].shape)
print(imgs[0].dtype)
# Out:
# 1
# (1, 755, 927, 3)
# float32

# %%
plt.figure()
plt.imshow(imgs[0][0,:,:,:])
plt.show()

# %%
patch_size = 64

# %%
# Patches are extracted from all images and combined into a single numpy array
patch_shape = (patch_size,patch_size)
patches = datagen.generate_patches_from_list(imgs, shape=patch_shape)
# Out:
# Generated patches: (1232, 64, 64, 3)

# %%
patches.shape
# Out:
# (1232, 64, 64, 3)

# %%
train_val_split = int(patches.shape[0] * 0.8)
X = patches[:train_val_split]
X_val = patches[train_val_split:]

# %%
print(X.shape)
print(X.dtype)
print(X_val.shape)
# Out:
# (985, 64, 64, 3)
# float32
# (247, 64, 64, 3)

# %%
datagen.generate_patches_from_list?

# %%
# Let's look at two patches.
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.imshow(X[0,...])
plt.title('Training Patch');
plt.subplot(1,2,2)
plt.imshow(X_val[0,...])
plt.title('Validation Patch');

# %%
# train_steps_per_epoch is set to (number of training patches)/(batch size), like this each training patch
# is shown once per epoch.
train_batch = 32
config = N2VConfig(X, unet_kern_size=3,
                   unet_n_first=64, unet_n_depth=3, train_steps_per_epoch=int(X.shape[0]/train_batch), train_epochs=20, train_loss='mse',
                   batch_norm=True, train_batch_size=train_batch, n2v_perc_pix=0.198, n2v_patch_shape=(patch_size, patch_size),
                   n2v_manipulator='uniform_withCP', n2v_neighborhood_radius=5, single_net_per_channel=False)

# Let's look at the parameters stored in the config-object.
vars(config)
# Out:
# {'means': ['0.58487886', '0.58487886', '0.58487886'],
#  'stds': ['0.17356652', '0.17356652', '0.17356652'],
#  'n_dim': 2,
#  'axes': 'YXC',
#  'n_channel_in': 3,
#  'n_channel_out': 3,
#  'unet_residual': False,
#  'unet_n_depth': 3,
#  'unet_kern_size': 3,
#  'unet_n_first': 64,
#  'unet_last_activation': 'linear',
#  'unet_input_shape': (None, None, 3),
#  'train_loss': 'mse',
#  'train_epochs': 20,
#  'train_steps_per_epoch': 30,
#  'train_learning_rate': 0.0004,
#  'train_batch_size': 32,
#  'train_tensorboard': True,
#  'train_checkpoint': 'weights_best.h5',
#  'train_reduce_lr': {'factor': 0.5, 'patience': 10},
#  'batch_norm': True,
#  'n2v_perc_pix': 0.198,
#  'n2v_patch_shape': (64, 64),
#  'n2v_manipulator': 'uniform_withCP',
#  'n2v_neighborhood_radius': 5,
#  'single_net_per_channel': False,
#  'blurpool': False,
#  'skip_skipone': False,
#  'structN2Vmask': None,
#  'probabilistic': False}

# %%
# a name used to identify the model --> change this to something sensible!
model_name = 'n2v_2D_xray'
# the base directory in which our model will live
basedir = 'models'
# We are now creating our network model.
model = N2V(config, model_name, basedir=basedir)

# %%
history = model.train(X, X_val)
# Out:
# 8 blind-spots will be generated per training patch of size (64, 64).
# Preparing validation data: 100%|██████████| 247/247 [00:00<00:00, 688.76it/s]
# Epoch 1/20
# 3/3 [==============================] - 1s 59ms/step
# 30/30 [==============================] - 248s 8s/step - loss: 0.2361 - n2v_mse: 0.2361 - n2v_abs: 0.3122 - val_loss: 0.5290 - val_n2v_mse: 0.5271 - val_n2v_abs: 0.6368 - lr: 4.0000e-04
# Epoch 2/20
# 3/3 [==============================] - 0s 61ms/step
# 30/30 [==============================] - 227s 8s/step - loss: 0.0560 - n2v_mse: 0.0560 - n2v_abs: 0.1836 - val_loss: 0.4566 - val_n2v_mse: 0.4552 - val_n2v_abs: 0.5945 - lr: 4.0000e-04
# Epoch 3/20
# 3/3 [==============================] - 0s 59ms/step
# 30/30 [==============================] - 227s 8s/step - loss: 0.0414 - n2v_mse: 0.0414 - n2v_abs: 0.1557 - val_loss: 0.3837 - val_n2v_mse: 0.3821 - val_n2v_abs: 0.5395 - lr: 4.0000e-04
# Epoch 4/20
# 3/3 [==============================] - 0s 59ms/step
# 30/30 [==============================] - 226s 8s/step - loss: 0.0473 - n2v_mse: 0.0473 - n2v_abs: 0.1685 - val_loss: 0.3627 - val_n2v_mse: 0.3614 - val_n2v_abs: 0.5260 - lr: 4.0000e-04
# Epoch 5/20
# 3/3 [==============================] - 0s 58ms/step
# 30/30 [==============================] - 222s 7s/step - loss: 0.0307 - n2v_mse: 0.0307 - n2v_abs: 0.1322 - val_loss: 0.2911 - val_n2v_mse: 0.2902 - val_n2v_abs: 0.4721 - lr: 4.0000e-04
# Epoch 6/20
# 3/3 [==============================] - 0s 59ms/step
# 30/30 [==============================] - 217s 7s/step - loss: 0.0275 - n2v_mse: 0.0275 - n2v_abs: 0.1334 - val_loss: 0.2848 - val_n2v_mse: 0.2837 - val_n2v_abs: 0.4656 - lr: 4.0000e-04
# Epoch 7/20
# 3/3 [==============================] - 0s 99ms/step
# 30/30 [==============================] - 217s 7s/step - loss: 0.0313 - n2v_mse: 0.0313 - n2v_abs: 0.1337 - val_loss: 0.2018 - val_n2v_mse: 0.2012 - val_n2v_abs: 0.3898 - lr: 4.0000e-04
# Epoch 8/20
# 3/3 [==============================] - 0s 59ms/step
# 30/30 [==============================] - 218s 7s/step - loss: 0.0281 - n2v_mse: 0.0281 - n2v_abs: 0.1242 - val_loss: 0.2100 - val_n2v_mse: 0.2093 - val_n2v_abs: 0.3978 - lr: 4.0000e-04
# Epoch 9/20
# 3/3 [==============================] - 0s 64ms/step
# 30/30 [==============================] - 219s 7s/step - loss: 0.0332 - n2v_mse: 0.0332 - n2v_abs: 0.1365 - val_loss: 0.1090 - val_n2v_mse: 0.1086 - val_n2v_abs: 0.2822 - lr: 4.0000e-04
# Epoch 10/20
# 3/3 [==============================] - 0s 61ms/step
# 30/30 [==============================] - 217s 7s/step - loss: 0.0293 - n2v_mse: 0.0293 - n2v_abs: 0.1280 - val_loss: 0.1565 - val_n2v_mse: 0.1560 - val_n2v_abs: 0.3363 - lr: 4.0000e-04
# Epoch 11/20
# 3/3 [==============================] - 0s 59ms/step
# 30/30 [==============================] - 217s 7s/step - loss: 0.0328 - n2v_mse: 0.0328 - n2v_abs: 0.1304 - val_loss: 0.0576 - val_n2v_mse: 0.0576 - val_n2v_abs: 0.2051 - lr: 4.0000e-04
# Epoch 12/20
# 3/3 [==============================] - 0s 65ms/step
# 30/30 [==============================] - 218s 7s/step - loss: 0.0258 - n2v_mse: 0.0258 - n2v_abs: 0.1188 - val_loss: 0.0705 - val_n2v_mse: 0.0705 - val_n2v_abs: 0.2314 - lr: 4.0000e-04
# Epoch 13/20
# 3/3 [==============================] - 0s 61ms/step
# 30/30 [==============================] - 215s 7s/step - loss: 0.0249 - n2v_mse: 0.0249 - n2v_abs: 0.1189 - val_loss: 0.0396 - val_n2v_mse: 0.0393 - val_n2v_abs: 0.1536 - lr: 4.0000e-04
# Epoch 14/20
# 3/3 [==============================] - 0s 65ms/step
# 30/30 [==============================] - 217s 7s/step - loss: 0.0231 - n2v_mse: 0.0231 - n2v_abs: 0.1133 - val_loss: 0.0273 - val_n2v_mse: 0.0273 - val_n2v_abs: 0.1368 - lr: 4.0000e-04
# Epoch 15/20
# 3/3 [==============================] - 0s 65ms/step
# 30/30 [==============================] - 216s 7s/step - loss: 0.0369 - n2v_mse: 0.0369 - n2v_abs: 0.1469 - val_loss: 0.0287 - val_n2v_mse: 0.0287 - val_n2v_abs: 0.1347 - lr: 4.0000e-04
# Epoch 16/20
# 3/3 [==============================] - 0s 95ms/step
# 30/30 [==============================] - 216s 7s/step - loss: 0.0189 - n2v_mse: 0.0189 - n2v_abs: 0.0999 - val_loss: 0.0214 - val_n2v_mse: 0.0214 - val_n2v_abs: 0.1216 - lr: 4.0000e-04
# Epoch 17/20
# 3/3 [==============================] - 0s 67ms/step
# 30/30 [==============================] - 217s 7s/step - loss: 0.0181 - n2v_mse: 0.0181 - n2v_abs: 0.1005 - val_loss: 0.0168 - val_n2v_mse: 0.0168 - val_n2v_abs: 0.1061 - lr: 4.0000e-04
# Epoch 18/20
# 3/3 [==============================] - 0s 59ms/step
# 30/30 [==============================] - 215s 7s/step - loss: 0.0242 - n2v_mse: 0.0242 - n2v_abs: 0.1170 - val_loss: 0.0221 - val_n2v_mse: 0.0222 - val_n2v_abs: 0.1256 - lr: 4.0000e-04
# Epoch 19/20
# 3/3 [==============================] - 0s 60ms/step
# 30/30 [==============================] - 216s 7s/step - loss: 0.0240 - n2v_mse: 0.0240 - n2v_abs: 0.1108 - val_loss: 0.0193 - val_n2v_mse: 0.0190 - val_n2v_abs: 0.0940 - lr: 4.0000e-04
# Epoch 20/20
# 3/3 [==============================] - 0s 59ms/step
# 30/30 [==============================] - 216s 7s/step - loss: 0.0150 - n2v_mse: 0.0150 - n2v_abs: 0.0924 - val_loss: 0.0108 - val_n2v_mse: 0.0107 - val_n2v_abs: 0.0822 - lr: 4.0000e-04
#
# Loading network weights from 'weights_best.h5'.

# %%
print(sorted(list(history.history.keys())))
plt.figure(figsize=(16,5))
plot_history(history,['loss','val_loss']);
# Out:
# ['loss', 'lr', 'n2v_abs', 'n2v_mse', 'val_loss', 'val_n2v_abs', 'val_n2v_mse']

# %% [markdown]
# **Denoising Image using Trained Model**

# %%
# We import all our dependencies.
from n2v.models import N2V
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.image import imread, imsave
from csbdeep.io import save_tiff_imagej_compatible

# %%
# A previously trained model is loaded by creating a new N2V-object without providing a 'config'.
model_name = 'n2v_2D_xray'
basedir = 'models'
model = N2V(config=None, name=model_name, basedir=basedir)
# Out:
# Loading network weights from 'weights_best.h5'.

# %%
from skimage.io import imread

# Load the image
img = imread('/content/Chest.png')

# Check the shape and data type of the image
print('Original image shape:', img.shape)
print('Original image data type:', img.dtype)

# If the image has four channels (RGBA), remove the alpha channel
if img.shape[2] == 4:
    img = img[:, :, :3]

# Check the new shape and data type after removing the alpha channel
print('Image shape without alpha:', img.shape)
print('Image data type without alpha:', img.dtype)
# Out:
# Original image shape: (755, 927, 3)
# Original image data type: uint8
# Image shape without alpha: (755, 927, 3)
# Image data type without alpha: uint8

# %%
pred = model.predict(img, axes='YXC')
# Out:
# The input image is of type uint8 and will be casted to float32 for prediction.
# 1/1 [==============================] - 10s 10s/step

# %%
pred.shape
# Out:
# (755, 927, 3)

# %%
# Let's look at the results.
plt.figure(figsize=(16, 8))

plt.subplot(1, 2, 1)
plt.imshow(img / 255.0)
plt.title('Input')

plt.subplot(1, 2, 2)
plt.imshow(pred / 255.0)

plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
